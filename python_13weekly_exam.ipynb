# %% [markdown]
# <a href="https://colab.research.google.com/github/jeroi07/Python_PGM/blob/main/python_13weekly_exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import In
#from google.colab import files
#uploaded = files.upload()

import xml.etree.ElementTree as ET

tree = ET.parse('menu.xml')  # 업로드한 파일명 그대로
root = tree.getroot()

print("최상위 태그:", root.tag)


for child in root:
    print("tag:", child.tag, "attributes:", child.attrib)
    for grandchild in child:
      print('tag:',grandchild.tag,'attributes:',grandchild.attrib)

print(root[0])
print(root[0].get("hours"))
print(root[0].keys())
print(root[0].items())
print(root[0].findall('items'))

#태그안의 내용 프린트
print(root[0].findall('items'))
for item in root[0].findall('item'):
     print(item.get('price'))
     print(item.text)

#json 파이썬 자료형을 json 문자열로 만들기
import json
j1 = {"name":"홍길동","birth":"0525","age":30}
j1
{'age':30, 'birth':'0525','name':'홍길동'}
json.dumps(j1)
'{"age":30,"birth":"0525","name":"\\ubc\\uc751\\uc69"}'

print(json.dumps(j1, indent=2))
{
"age": 30,
"birth": "0525",
"name": "\ubc15\uc751\uc6a9"
}

json.dumps([1,2,3])
json.dumps((4,5,6))

j1 = {"name":"홍길동", "birth":"0525", "age": 30}
d1 = json.dumps(j1)
json.loads(d1)
{'name': '홍길동', 'birth': '0525', 'age': 30}

{
"name": "홍길동",
"birth": "0525",
"age": 30
}

#with open('./myinfo.json') as f:
#data = json.load(f)

##print(type(data))
#<class 'dict>
#print(data)
#{'name': '홍길동', 'birth': '0525', 'age': 30}

#웹스크래핑
from urllib.request import urlopen
html = urlopen("https://www.yes24.com/campaign/01_Book/yesFunding/yesFundingBook.aspx?EventNo=259223")
print(html.read())

from urllib.request import urlopen

# 웹 페이지 요청
#url = "http://pythonscraping.com/pages/page1.html"
#response = urlopen(url)

# HTML 페이지 내용 출력 (디코딩 포함)
#html = response.read().decode("utf-8")
#print(html)



from bs4 import BeautifulSoup

html = """
<html>
  <head><title>테스트</title></head>
  <body><h1>Hello Python!</h1></body>
</html>
"""

soup = BeautifulSoup(html, "html.parser")
print(soup.h1)
# Out:
# 최상위 태그: menu
# tag: breakfast attributes: {'hours': '7-11'}
# tag: item attributes: {'price': '$6.00'}
# tag: item attributes: {'price': '$4.00'}
# tag: lunch attributes: {'hours': '11-3'}
# tag: item attributes: {'price': '$5.00'}
# tag: dinner attributes: {'hours': '3-10'}
# tag: item attributes: {'price': '8.00'}
# <Element 'breakfast' at 0x7a5687c2c680>
# 7-11
# ['hours']
# [('hours', '7-11')]
# []
# []
# $6.00
# breakfast burritos
# $4.00
# pancakes
# {
#   "name": "\ud64d\uae38\ub3d9",
#   "birth": "0525",
#   "age": 30
# }
# ...
